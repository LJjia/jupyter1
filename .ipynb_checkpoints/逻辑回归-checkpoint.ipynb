# %% [markdown]
# # 回归 源于 最佳拟合
#
# 表示要找到最佳拟合数据集

# %% [markdown]
# 经典的阶跃函数由于其在0处的特殊性
# 会非常难以处理，因此使用sigmoid函数代替阶跃函数

# %%
#梯度上升算法  类似于梯度下降算法

from numpy import *

laptop_path_test='D:/PythonCode/Machine/machinelearninginaction/Ch05/'
desktop_path_test='D:/PythonCode/machinelearninginaction/Ch05/'
def loadDataSet():
    dataMat=[];labelMat=[]
    fr=open(laptop_path_test+'testSet.txt')
    for line in fr.readlines():
        lineArr=line.strip().split()
        dataMat.append([1.0,float(lineArr[0]),float(lineArr[1])])
        #一共x0，x1，x2三个值输入数据列表中 ，x0默认为1.0
        labelMat.append(int(lineArr[2]))#标签
    return dataMat,labelMat

def sigmoid(inX):
    return 1.0/(1+exp(-inX))

#梯度上升算法
def gradAscent(dataMatIn,classLabels):
    #转换为Numpy矩阵数据类型
    dataMatrix=mat(dataMatIn)#100*3
    lableMat=mat(classLabels).transpose()#这里是转置的意思
    m,n=shape(dataMatrix)
    print('m',m,'n',n)
    alpha=0.001
    maxCycles=500#迭代次数
    weights=ones((n,1))
    #print(weights)
    #矩阵相乘
    for  k  in range(maxCycles):
        h=sigmoid(dataMatrix*weights)#100*1
        error=(lableMat-h)#error 为100*1矩阵
        if k==499:
            print('最后一次误差',error)
        weights=weights+alpha*dataMatrix.transpose()*error#dataMatrix转置*error
    print(type(weights),weights)
    return weights

# %%
dataArr,labelMat=loadDataSet()
weights=gradAscent(dataArr,labelMat)
# Out:
# m 100 n 3
# 最后一次误差 [[-0.01045389]
#  [ 0.35961177]
#  [-0.43274299]
#  [-0.28437375]
#  [-0.07653053]
#  [ 0.51014335]
#  [-0.03188788]
#  [ 0.78455774]
#  [-0.18360635]
#  [-0.08948868]
#  [ 0.43464434]
#  [-0.03374723]
#  [ 0.06104706]
#  [-0.0876783 ]
#  [ 0.42431422]
#  [ 0.0269122 ]
#  [ 0.42140316]
#  [ 0.07984508]
#  [ 0.02292291]
#  [ 0.25724748]
#  [ 0.04386377]
#  [ 0.02528574]
#  [-0.03178037]
#  [ 0.00676561]
#  [ 0.18937548]
#  [-0.22957521]
#  [-0.1370526 ]
#  [ 0.03322162]
#  [ 0.10908774]
#  [-0.24433184]
#  [ 0.18598669]
#  [ 0.67376216]
#  [-0.08059731]
#  [ 0.00698354]
#  [ 0.16213642]
#  [-0.16381662]
#  [-0.19683227]
#  [-0.06488128]
#  [-0.01626802]
#  [-0.03170105]
#  [ 0.13303646]
#  [ 0.29787599]
#  [-0.07322382]
#  [ 0.01292767]
#  [ 0.05372432]
#  [-0.04853496]
#  [ 0.00589355]
#  [ 0.35883547]
#  [-0.03039188]
#  [-0.08171567]
#  [-0.2374704 ]
#  [-0.08203218]
#  [-0.26163639]
#  [-0.01894383]
#  [ 0.14872764]
#  [ 0.51129541]
#  [-0.06594179]
# ...

# %%
#画出数据集和逻辑回归最佳拟合直线
import matplotlib.pyplot as plt
def plotBestFit(wei):
    #getA()函数：将矩阵变成ndarray类型，或者使用 np.asarray()函数 这里是把矩阵类型转化为向量类型
    weights=mat(wei)#首先weights要矩阵的形式，才能在plot中输出（其中getA只支持矩阵）
    weights=weights.reshape(3,1)#其外weights必须是3*1
    weights = weights.getA()
    dataMat,labelMat=loadDataSet()
    dataArr=array(dataMat)
    n=shape(dataArr)[0]#行
    xcord1=[];ycord1=[]
    xcord2=[];ycord2=[]
    for i in range(n):
        if int(labelMat[i])==1:
            xcord1.append(dataArr[i,1]);ycord1.append(dataArr[i,2])
        else:
            xcord2.append(dataArr[i,1]);ycord2.append(dataArr[i,2])
    fig=plt.figure()
    ax=fig.add_subplot(111)
    #画散点图
    ax.scatter(xcord1,ycord1,s=30,c='red',marker='s')
    ax.scatter(xcord2,ycord2,s=30,c='green')
    x=arange(-3.0,3.0,0.1)#创建等差数组
    #最佳拟合直线
    #x=x.reshape(1,-1)
    print(weights)
    y=(-weights[0]-weights[1]*x)/weights[2]
    
    print(x.shape,y.shape)
    #画直线a*x+b*y+c=0因为0这个点刚好是区分两个类别的分界点
    ax.plot(x,y)
    plt.xlabel('X1');plt.ylabel('X2')
    plt.show()

# %%
plotBestFit(weights)
# Out:
# [[ 4.12414349]
#  [ 0.48007329]
#  [-0.6168482 ]]
# (60,) (60,)

# %% [markdown]
# # 随机梯度上升法

# %%
def stocGradAscent0(dataMatrix,classLabels,weightsIn):
    m,n=shape(dataMatrix)
    alpha=0.01
    weights=weightsIn.getA()
    weights=weights.reshape(1,-1)
    print(type(weights),weights)
    #weights=ones(n)
#     print('origin weights',weights)
    for i in range(m):
#         print('dataMatrix',dataMatrix[i])
        h=sigmoid(sum(dataMatrix[i]*weights))
#         print('h',h)
        error=classLabels[i]-h
#         print('error',error)
        weights=weights+alpha*error*dataMatrix[i]
        if i==m-1:
            print('error',error)
    weights=mat(weights)#首先weights要矩阵的形式，才能在plot中输出（其中getA只支持矩阵）
    weights=weights.reshape(3,1)#其外weights必须是3*1
    print(type(weights),weights)
    return weights

# %%
dataArr,labelMat=loadDataSet()
for i in range(50):#进行50次优化
    weights=stocGradAscent0(array(dataArr),labelMat,weights)
plotBestFit(weights)
# Out:
# <class 'numpy.ndarray'> [[ 4.12414349  0.48007329 -0.6168482 ]]
# error -0.0036157705580563597
# <class 'numpy.matrixlib.defmatrix.matrix'> [[ 4.15272674]
#  [ 0.48681496]
#  [-0.67397835]]
# <class 'numpy.ndarray'> [[ 4.15272674  0.48681496 -0.67397835]]
# error -0.0035007850130938673
# <class 'numpy.matrixlib.defmatrix.matrix'> [[ 4.18760705]
#  [ 0.49169984]
#  [-0.67863341]]
# <class 'numpy.ndarray'> [[ 4.18760705  0.49169984 -0.67863341]]
# error -0.0033953186117309016
# <class 'numpy.matrixlib.defmatrix.matrix'> [[ 4.22204542]
#  [ 0.49626419]
#  [-0.68313511]]
# <class 'numpy.ndarray'> [[ 4.22204542  0.49626419 -0.68313511]]
# error -0.003295154801780918
# <class 'numpy.matrixlib.defmatrix.matrix'> [[ 4.25604356]
#  [ 0.50054886]
#  [-0.68755757]]
# <class 'numpy.ndarray'> [[ 4.25604356  0.50054886 -0.68755757]]
# error -0.003199849717783375
# <class 'numpy.matrixlib.defmatrix.matrix'> [[ 4.28961198]
#  [ 0.50458734]
#  [-0.69190559]]
# ...

# %%
def stocGradAscent1(dataMatrix,classLabels,numIter=150):
    m,n=shape(dataMatrix)
    weights=ones(n)
    for j in range(numIter):
        dataIndex=list(range(m))#每次随机选取m个长度
        for i in range(m):
            #alpha 每次迭代时需要调整
            alpha=4/(1.0+i+j)+0.01#alpha每次迭代都会调整 会缓解高频波动，即一些噪声造成的数据最佳拟合直线不准
            #要注意这里aplha并非严格下降
            #随机选取更新
            randIndex=int(random.uniform(0,len(dataIndex)))
            h=sigmoid(sum(dataMatrix[randIndex]*weights))
            error=classLabels[randIndex]-h
            weights=weights+alpha*error*dataMatrix[randIndex]
            del(dataIndex[randIndex])#执行完一个数据后就把这个数据删除，数据不重样
    return weights

'''随机选取会避免出现周期性的波动，而动态aplha和随机则使得收敛更快'''
# Out:
# '随机选取会避免出现周期性的波动，而动态aplha和随机则使得收敛更快'

# %%
dataArr,labelMat=loadDataSet()
weights=stocGradAscent1(array(dataArr),labelMat)
plotBestFit(weights)
# Out:
# [[14.34219001]
#  [ 1.13229392]
#  [-1.9085112 ]]
# (60,) (60,)

# %% [markdown]
# # 示例 预测马匹是否患病

# %%
laptop_path_test='D:/PythonCode/Machine/machinelearninginaction/Ch05/'
desktop_path_test='D:/PythonCode/machinelearninginaction/Ch05/'

#以回归系数和特征向量作为输入计算对应sigmoid值，返回0或1
def classifyVector(inX,weights):
    prob=sigmoid(sum(inX*weights))
    if prob>0.5:
        return 1.0
    else:
        return 0.0
    
def colicTest(num):
    frTrain=open(laptop_path_test+'horseColicTraining.txt')
    frTest=open(laptop_path_test+'horseColicTest.txt')
    trainingSet=[];trainingLabels=[]
    #for 循环 导入训练数据
    for line in frTrain.readlines():
        currLine=line.strip().split('\t')
        lineArr=[]
        for i in range(21):
            lineArr.append(float(currLine[i]))
        trainingSet.append(lineArr)
        trainingLabels.append(float(currLine[21]))
    #训练数据
    trainWeights=stocGradAscent1(array(trainingSet),trainingLabels,500*num)
    errorCount=0;numTestVec=0.0
    #导入测试数据
    for line in frTest.readlines():
        numTestVec+=1.0
        currLine=line.strip().split('\t')
        lineArr=[]
        for i in range(21):
            lineArr.append(float(currLine[i]))
        #逐个检测
        if int(classifyVector(array(lineArr),trainWeights))!=int(currLine[21]):
            errorCount+=1
    errorRate=(float(errorCount)/numTestVec)
    print('the error rate of this test is:%f'%errorRate)
    return errorRate

#多重测试返回平均错误率
def multiTest():
    numTests=10;errorSum=0.0
    for k in range(numTests):
        errorSum+=colicTest(k)
    print('after %d iterations the average error rate is:%f'%(numTests,errorSum/float(numTests)))

# %%
multiTest()
# Out:
# the error rate of this test is:0.298507
# H:\Anaconda\lib\site-packages\ipykernel_launcher.py:18: RuntimeWarning: overflow encountered in exp
# the error rate of this test is:0.552239
# the error rate of this test is:0.373134
# the error rate of this test is:0.358209
# the error rate of this test is:0.313433
# the error rate of this test is:0.268657
# the error rate of this test is:0.313433
# the error rate of this test is:0.268657
# the error rate of this test is:0.432836
# the error rate of this test is:0.432836
# after 10 iterations the average error rate is:0.361194
